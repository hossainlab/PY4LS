# %%
import pandas as pd

# %%
data = pd.read_excel("BLOOD.DAT.xls")

# %%
data
# Out:
#          ID  matchid  case  curpmh  ageblood  estradol  estrone  testost  \
# 0    100013   164594     0       1        46        57       65       25
# 1    100241   107261     0       0        65        11       26      999
# 2    100696   110294     0       1        66         3      999        8
# 3    101266   101266     1       0        57         4       18        6
# 4    101600   101600     1       0        66         6       18       25
# ..      ...      ...   ...     ...       ...       ...      ...      ...
# 505  364694   364694     1       0        66         9       22       40
# 506  366149   348025     0       0        61         5       20       18
# 507  367304   352008     0       0        64         5       37       19
# 508  367953   367953     1       1        57        24       50       54
# 509  368046   368046     1       0        61         9       25       32
#
#      prolactn
# 0       11.12
# 1        2.80
# 2       38.00
# 3        8.90
# ...
